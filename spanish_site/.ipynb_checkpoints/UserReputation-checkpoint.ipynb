# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
user_pv = pd.DataFrame.from_csv('user_post_votes.csv', index_col=None)
user_pv.head(15)
# Out:
#     UserId  UserViews  UserReputation  PostId  PostType  VoteType  \
# 0        3         44            1317       1         1         2
# 1        3         44            1317       1         1         2
# 2        3         44            1317       1         1         2
# 3        3         44            1317       1         1         2
# 4        3         44            1317       1         1         2
# 5        3         44            1317       1         1         2
# 6        3         44            1317       1         1         2
# 7        3         44            1317       1         1         2
# 8        3         44            1317       1         1         2
# 9        3         44            1317       1         1         2
# 10       3         44            1317       1         1         2
# 11       3         44            1317       1         1         2
# 12      10         25             708       2         1         2
# ...

# %%
users = user_pv[['UserId','UserViews','UserReputation','PostId','PostType']]

# %%
predictors = ["Reputation","Views","PostsContributed","VotesRecQ","VotesRecAns"]
pr_values = lambda df: [[df.UserReputation.iloc[0]],[df.UserViews.iloc[0]],[df['PostId'].unique().size], [sum(df.PostType==1)], [sum(df.PostType==2)]]
ff = lambda df : pd.DataFrame(data=dict(zip(predictors,pr_values(df))))
users = users.groupby(['UserId']).apply(ff).reset_index(level=[1],drop=True)
users.head(15)
# Out:
#         PostsContributed  Reputation  Views  VotesRecAns  VotesRecQ
# UserId
# 3                     17        1317     44           90         60
# 5                      3         205      5            4         12
# 6                      6         460     11            0         69
# 8                      3         226      6           11          0
# 9                      1         111      0            1          0
# 10                     8         708     25           56         12
# 12                   157        6139    375          289        625
# 15                     2         153      6            5          0
# 18                     2         380      0            0         55
# 19                     1         111      7            0          3
# 22                     1         115      4            0          7
# 23                     5         579      7           46          0
# 25                     6         328      5           13         21
# ...

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
users.describe()
# Out:
#        PostsContributed    Reputation        Views  VotesRecAns    VotesRecQ
# count       1959.000000   1959.000000  1959.000000  1959.000000  1959.000000
# mean           4.809086    199.009699     3.849923    11.979581     5.527310
# std           16.889362    669.354065    17.781874    52.105374    34.421235
# min            1.000000      1.000000     0.000000     0.000000     0.000000
# 25%            1.000000     11.000000     0.000000     0.000000     0.000000
# 50%            1.000000     66.000000     1.000000     1.000000     0.000000
# 75%            3.000000    146.000000     2.000000     5.000000     3.000000
# max          372.000000  15418.000000   375.000000  1250.000000  1091.000000

# %%
users.Reputation.quantile([.75, .85, .95])
# Out:
# 0.75    146.0
# 0.85    213.3
# 0.95    701.1
# Name: Reputation, dtype: float64

# %%
mod_ols = smf.ols(formula='Reputation ~ Views + PostsContributed + VotesRecAns + VotesRecQ', data= users[users.Reputation>=210])
res = mod_ols.fit()
print res.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Reputation   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 1.630e+04
# Date:                Thu, 07 Apr 2016   Prob (F-statistic):               0.00
# Time:                        02:10:49   Log-Likelihood:                -1802.5
# No. Observations:                 299   AIC:                             3615.
# Df Residuals:                     294   BIC:                             3634.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept           62.6443      6.833      9.168      0.000        49.197    76.092
# ...
