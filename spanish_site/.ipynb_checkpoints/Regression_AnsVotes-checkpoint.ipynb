# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
votes = pd.DataFrame.from_csv('AnsVotes_TSeries_normalized.csv', index_col=None)
votes.head(10)
# Out:
#    Unnamed: 0  QuestionId  AnsId  Age_vot  AnsWordCount  AcceptedAnsId  \
# 0           0           1     56        0           201             56
# 1           1           2     10        0           145             10
# 2           2           2     10        0           145             10
# 3           3           3      9        0            25            109
# 4           4           7     16        0            45           2977
# 5           5          14     20        0            28             20
# 6           6          18     33        0           133             33
# 7           7          18     33        0           133             33
# 8           8          18     33        0           133             33
# 9           9          21     80        0            43             80
#
#    QScore  QVotes  Score  Votes              ...               log_QScore  \
# 0       0       0      2      2              ...                   1.9459
# 1       0       0      3      3              ...                   1.9459
# 2       0       0      3      3              ...                   1.9459
# 3       0       0      4      4              ...                   1.9459
# 4       0       0      3      3              ...                   1.9459
# 5       0       0      7      7              ...                   1.9459
# 6       0       0      3      3              ...                   1.9459
# 7       0       0      3      3              ...                   1.9459
# 8       0       0      3      3              ...                   1.9459
# 9       0       0      1      1              ...                   1.9459
#
#    log_Score  log_CumScore  log_ReScore  log_QReScore  Social_signal  \
# 0     1.6094        2.1972       0.4329       -0.1335         0.0000
# 1     1.7918        2.3026       0.4855       -0.1335         0.0000
# 2     1.7918        2.3026       0.4855       -0.1335         1.3764
# 3     1.9459        2.3979       0.5158       -0.1335         1.3764
# 4     1.7918        2.3026       0.4855       -0.1335         1.3764
# 5     2.3026        2.6391       0.5596       -0.1335         1.3764
# 6     1.7918        2.3026       0.4855       -0.1335         1.3764
# 7     1.7918        2.3026       0.4855       -0.1335         1.3764
# 8     1.7918        2.3026       0.4855       -0.1335         1.3764
# 9     1.3863        2.0794       0.3185       -0.1335         1.3764
#
#    ReScore_x_EPbias_x_Social_signal  ReScore_x_EPbias_x_log_Comments  \
# 0                           -1.0033                           0.0526
# 1                           -1.0033                           0.0526
# 2                            1.0439                           0.0526
# 3                            1.1804                           0.0526
# 4                            1.0439                           0.0526
# 5                            1.3851                           0.0526
# 6                            1.0439                           0.0526
# 7                            1.0439                           0.0526
# 8                            1.0439                           0.0526
# 9                            0.3615                           0.0526
#
#    ReScore_x_EPbias_x_log_AnsWordCount  ReScore_x_EPbias_x_log_Score
# 0                               1.3787                           NaN
# 1                               1.4587                           NaN
# 2                               1.4587                           NaN
# 3                               1.0041                           NaN
# 4                               1.1106                           NaN
# 5                               1.1407                           NaN
# 6                               1.4328                           NaN
# 7                               1.4328                           NaN
# 8                               1.4328                           NaN
# 9                               0.7170                           NaN
#
# [10 rows x 37 columns]

# %%
votes.columns
# Out:
# Index([u'Unnamed: 0', u'QuestionId', u'AnsId', u'Age_vot', u'AnsWordCount',
#        u'AcceptedAnsId', u'QScore', u'QVotes', u'Score', u'Votes', u'CumVotes',
#        u'CumScore', u'ReScore', u'QReScore', u'Comments', u'AnsRank',
#        u'ReScore_rank', u'Ans_count', u'Pbias', u'DRank', u'EPbias',
#        u'log_Comments', u'log_AnsWordCount', u'log_QVotes', u'log_Votes',
#        u'log_CumVotes', u'log_DRank', u'log_QScore', u'log_Score',
#        u'log_CumScore', u'log_ReScore', u'log_QReScore', u'Social_signal',
#        u'ReScore_x_EPbias_x_Social_signal', u'ReScore_x_EPbias_x_log_Comments',
#        u'ReScore_x_EPbias_x_log_AnsWordCount',
#        u'ReScore_x_EPbias_x_log_Score'],
#       dtype='object')

# %%
votes[['Age_vot','AnsWordCount','Comments','Ans_count','Votes']].describe()
# Out:
#             Age_vot  AnsWordCount      Comments     Ans_count         Votes
# count  23328.000000  23328.000000  23328.000000  23328.000000  23328.000000
# mean     212.595508    143.485039      2.033522      2.721622      1.445773
# std      380.532603    150.314528      2.851866      2.061537      1.040349
# min        0.000000      3.000000      0.000000      1.000000      1.000000
# 25%        1.000000     51.000000      0.000000      1.000000      1.000000
# 50%        7.000000     97.000000      1.000000      2.000000      1.000000
# 75%      231.000000    178.000000      3.000000      3.000000      1.000000
# max     1504.000000   2142.000000     18.000000     12.000000     12.000000

# %%
votes[['log_Comments','log_AnsWordCount','log_DRank','log_QScore','log_QVotes',
'log_Score','log_Votes','log_CumVotes','log_CumScore','log_ReScore','log_QReScore']].describe()
# Out:
#        log_Comments  log_AnsWordCount     log_DRank    log_QScore  \
# count  23328.000000      23328.000000  2.332800e+04  2.332800e+04
# mean       0.770312          4.558133          -inf          -inf
# std        0.792142          0.932438           NaN           NaN
# min        0.000000          1.386300          -inf          -inf
# 25%        0.000000          3.951200  1.945900e+00  2.197200e+00
# 50%        0.693100          4.585000  1.945900e+00  2.484900e+00
# 75%        1.386300          5.187400  1.945900e+00  2.833200e+00
# max        2.944400          7.670000  2.833200e+00  4.174400e+00
#
#          log_QVotes     log_Score     log_Votes  log_CumVotes  log_CumScore  \
# count  23328.000000  2.332800e+04  23328.000000  23328.000000  2.332800e+04
# mean       1.734719          -inf      0.839298      1.675927          -inf
# std        1.043817           NaN      0.296533      0.741073           NaN
# min        0.000000          -inf      0.693100      0.693100          -inf
# 25%        1.098600  1.386300e+00      0.693100      1.098600  2.197200e+00
# 50%        1.791800  1.386300e+00      0.693100      1.609400  2.397900e+00
# 75%        2.397900  1.386300e+00      0.693100      2.079400  2.639100e+00
# max        4.143100  2.708100e+00      2.564900      4.143100  4.143100e+00
#
#         log_ReScore  log_QReScore
# count  2.332800e+04  2.332800e+04
# mean           -inf          -inf
# std             NaN           NaN
# min            -inf          -inf
# 25%    4.329000e-01  4.055000e-01
# 50%    5.158000e-01  5.158000e-01
# 75%    5.596000e-01  5.738000e-01
# max    6.187000e-01  6.177000e-01

# %%
votes['Ans_count'].value_counts().head(15)
# Out:
# 1     7132
# 2     6866
# 3     4033
# 4     2172
# 5     1169
# 6      535
# 10     484
# 7      283
# 8      273
# 9      240
# 11      73
# 12      68
# Name: Ans_count, dtype: int64

# %%
#votes = votes[ votes.age_vot>=3]
votes_r = votes[votes.Age_vot<=7]
votes_r[['Score','Votes','CumScore','CumVotes','QScore','QVotes','ReScore','QReScore','Ans_count','DRank']].describe()
# Out:
#               Score         Votes      CumScore      CumVotes        QScore  \
# count  11949.000000  11949.000000  11949.000000  11949.000000  11949.000000
# mean       1.674785      1.787765      3.338020      3.505733      4.262030
# std        1.404004      1.326312      2.641695      2.575425      6.957248
# min       -3.000000      1.000000     -6.000000      1.000000     -7.000000
# 25%        1.000000      1.000000      1.000000      2.000000      0.000000
# 50%        1.000000      1.000000      3.000000      3.000000      3.000000
# 75%        2.000000      2.000000      5.000000      5.000000      6.000000
# max       12.000000     12.000000     18.000000     18.000000     58.000000
#
#              QVotes       ReScore      QReScore     Ans_count         DRank
# count  11949.000000  11949.000000  11949.000000  11949.000000  11949.000000
# mean       4.482802      0.667576      0.523072      1.892125      0.069462
# std        7.212644      0.233654      0.380433      1.204971      0.589805
# min        0.000000     -0.857143     -0.875000      1.000000     -4.000000
# 25%        0.000000      0.500000      0.000000      1.000000      0.000000
# 50%        3.000000      0.750000      0.666667      2.000000      0.000000
# 75%        6.000000      0.833333      0.833333      2.000000      0.000000
# max       62.000000      0.947368      0.979592      9.000000      8.000000

# %% [markdown]
# # Votes/day on a given answer . (Context information: question, ans aggregates)

# %%
#Comments Ans_count AnsWordCount DRank Age_vot 
mod_ols = smf.ols(formula='np.log(Votes+1) ~ ReScore + EPbias + Score + C(AnsRank,KRanks) -1', data=votes_r)#&(votes.DRank==2)])
res = mod_ols.fit()
print res.summary()
#TODO: regularize these contrasts
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(Votes + 1)   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     5993.
# Date:                Sat, 02 Apr 2016   Prob (F-statistic):               0.00
# Time:                        04:28:41   Log-Likelihood:                 6309.4
# No. Observations:               11949   AIC:                        -1.259e+04
# Df Residuals:                   11937   BIC:                        -1.251e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------------
# C(AnsRank, KRanks)[K-r.intercept]     0.7684      0.011     68.766      0.000         0.746     0.790
# C(AnsRank, KRanks)[K-r.2]             0.0016      0.001      1.124      0.261        -0.001     0.004
# C(AnsRank, KRanks)[K-r.3]            -0.0003      0.002     -0.200      0.841        -0.004     0.003
# C(AnsRank, KRanks)[K-r.4]            -0.0010      0.002     -0.427      0.670        -0.006     0.004
# C(AnsRank, KRanks)[K-r.5]            -0.0023      0.003     -0.673      0.501        -0.009     0.004
# C(AnsRank, KRanks)[K-r.6]            -0.0069      0.006     -1.227      0.220        -0.018     0.004
# C(AnsRank, KRanks)[K-r.7]             0.0009      0.010      0.097      0.923        -0.018     0.020
# C(AnsRank, KRanks)[K-r.8]            -0.0213      0.020     -1.087      0.277        -0.060     0.017
# C(AnsRank, KRanks)[K-r.9]            -0.0798      0.038     -2.120      0.034        -0.154    -0.006
# ReScore                              -0.4024      0.007    -60.584      0.000        -0.415    -0.389
# EPbias                                0.0011      0.007      0.166      0.868        -0.012     0.014
# Score                                 0.2628      0.001    237.532      0.000         0.261     0.265
# ==============================================================================
# Omnibus:                     4480.745   Durbin-Watson:                   1.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            59401.436
# Skew:                           1.426   Prob(JB):                         0.00
# Kurtosis:                      13.544   Cond. No.                         198.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod_poi = smf.glm('Votes ~ ReScore + EPbias + Score  - 1 ', data=votes,
                  family=sm.families.Poisson(link=sm.families.links.log)).fit(method='bfgs') #
#print mod_poi.mle_retvals['converged']
print mod_poi.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  Votes   No. Observations:                23328
# Model:                            GLM   Df Residuals:                    23325
# Model Family:                 Poisson   Df Model:                            2
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -26890.
# Date:                Sat, 02 Apr 2016   Deviance:                       2634.0
# Time:                        03:10:15   Pearson chi2:                 2.62e+03
# No. Iterations:                     8
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# ReScore       -0.3761      0.016    -24.106      0.000        -0.407    -0.346
# EPbias         0.1970      0.017     11.755      0.000         0.164     0.230
# Score          0.3150      0.003    105.583      0.000         0.309     0.321
# ==============================================================================

# %% [markdown]
# ## How does question quality relate to answer quality

# %%
#Comments Ans_count AnsWordCount DRank Age_vot
four_ans = smf.ols(formula='QReScore ~ ReScore + EPbias - 1 ', data=votes_r[votes_r['Ans_count']==4])
re_four = four_ans.fit()
print re_four.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               QReScore   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     1261.
# Date:                Sat, 02 Apr 2016   Prob (F-statistic):          6.16e-214
# Time:                        04:19:16   Log-Likelihood:                -181.87
# No. Observations:                 593   AIC:                             367.7
# Df Residuals:                     591   BIC:                             376.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# ReScore        0.4712      0.037     12.674      0.000         0.398     0.544
# EPbias         1.4124      0.092     15.303      0.000         1.231     1.594
# ==============================================================================
# Omnibus:                       36.424   Durbin-Watson:                   1.069
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.051
# Skew:                          -0.564   Prob(JB):                     2.72e-10
# Kurtosis:                       3.716   Cond. No.                         5.20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod_poi = smf.glm('QReScore ~ ReScore + EPbias - 1 ', data=votes[votes['Ans_count']==4],
                  family=sm.families.Poisson(link=sm.families.links.log)).fit(method='bfgs') #
#print mod_poi.mle_retvals['converged']
print mod_poi.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               QReScore   No. Observations:                 2172
# Model:                            GLM   Df Residuals:                     2170
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -2016.8
# Date:                Sat, 02 Apr 2016   Deviance:                       168.97
# Time:                        04:19:41   Pearson chi2:                     143.
# No. Iterations:                     7
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# ReScore        0.0081      0.067      0.121      0.904        -0.123     0.139
# EPbias        -0.7037      0.172     -4.091      0.000        -1.041    -0.367
# ==============================================================================

# %%
levels = [e+1 for e in range(5)]
contrast = KRanks().code_without_intercept(levels)
print contrast.matrix
# Out:
# [[ 4.  0.  0.  0.]
#  [-1.  3.  0.  0.]
#  [-1. -1.  2.  0.]
#  [-1. -1. -1.  1.]
#  [-1. -1. -1. -1.]]

# %%
class KRanks(object):
    """K-rank contrasts.
       Compare relative effect on output variable for a given level
       against all those below.
       
       # Reduced rank
       dmatrix("C(a, KRanks)", balanced(a=4))
       # Full rank
       dmatrix("0 + C(a, KRanks)", balanced(a=4))
    """
    def _kranks_contrast(self, levels):
        n = len(levels)
        contr = np.zeros((n, n - 1))
        contr[:-1][np.diag_indices(n - 1)] = np.arange(1, n)[::-1]
        rows,cols = np.tril_indices(n-1)
        contr[(rows+1,cols)] = -1
        return contr

    def code_with_intercept(self, levels):
        contrast = np.column_stack((np.ones(len(levels)),
                                    self._kranks_contrast(levels)))
        column_suffixes = _name_levels("K-r.", ["intercept"] + list(levels[1:]))
        return ContrastMatrix(contrast, column_suffixes)

    def code_without_intercept(self, levels):
        contrast = self._kranks_contrast(levels)
        return ContrastMatrix(contrast, _name_levels("K-r.", levels[1:]))

# %%
np.arange(0, 0.26, 0.05)
# Out:
# array([ 0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25])
