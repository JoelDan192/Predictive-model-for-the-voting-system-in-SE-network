# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
a_questions = pd.DataFrame.from_csv('question_votes.csv', index_col=None)
a_questions[a_questions.AcceptedAnsId.notnull()].head()
# Out:
#    QuestionId         QuestionCreation     QuestionLastActivity  \
# 0           1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 1           1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 2           1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 3           1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 4           1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
#
#    AcceptedAnsId             AcceptedDate  VoteType            QVoteCreation
# 0             56  2011-11-21T00:00:00.000         2  2011-11-15T20:45:51.037
# 1             56  2011-11-21T00:00:00.000         2  2011-11-15T20:45:51.037
# 2             56  2011-11-21T00:00:00.000         2  2011-11-15T20:45:51.037
# 3             56  2011-11-21T00:00:00.000         2  2011-11-15T20:45:51.037
# 4             56  2011-11-21T00:00:00.000         2  2011-11-15T20:45:51.037

# %%
get_votes_qv = lambda df: pd.Series((df.VoteType==2).cumsum() + (df.VoteType==3).cumsum(),name='QVotes')
get_score_qv = lambda df: pd.Series((df.VoteType==2).cumsum() - (df.VoteType==3).cumsum(),name='QScore')

predictors_qvotes = ['QuestionId','QuestionCreation','QuestionLastActivity','AcceptedAnsId','AcceptedDate','QVoteCreation']
f_q = lambda df: pd.concat([df[cname] for cname in df.columns.values.tolist() if cname in predictors_qvotes]+[get_score_qv(df),get_votes_qv(df)],axis=1)
a_questions = a_questions.sort_values(by='QVoteCreation').groupby(['QuestionId']).apply(f_q)
a_questions.head(10)
# Out:
#     QuestionId         QuestionCreation     QuestionLastActivity  \
# 0            1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 11           1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 10           1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 9            1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 7            1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 6            1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 8            1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 4            1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 3            1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
# 2            1  2011-11-15T20:45:51.037  2015-10-21T09:57:50.000
#
#     AcceptedAnsId             AcceptedDate            QVoteCreation  QScore  \
# 0              56  2011-11-21T00:00:00.000  2011-11-15T20:45:51.037       1
# 11             56  2011-11-21T00:00:00.000  2011-11-15T20:45:51.037       2
# 10             56  2011-11-21T00:00:00.000  2011-11-15T20:45:51.037       3
# 9              56  2011-11-21T00:00:00.000  2011-11-15T20:45:51.037       4
# 7              56  2011-11-21T00:00:00.000  2011-11-15T20:45:51.037       5
# 6              56  2011-11-21T00:00:00.000  2011-11-15T20:45:51.037       6
# 8              56  2011-11-21T00:00:00.000  2011-11-15T20:45:51.037       7
# 26      2011-11-15T20:45:51.037       3       3
# 27      2011-11-15T20:45:51.037       4       4
# 28      2011-11-15T20:45:51.037       5       5
# 29      2011-11-15T20:45:51.037       6       6
# ...                         ...     ...     ...
# 154177  2015-12-28T18:47:08.423       2       2
# 154178  2015-12-30T00:22:21.153       1       1
# 154179  2015-12-30T00:22:21.153       1       1
# 154180  2015-12-30T00:22:21.153       1       1
# 154181  2015-12-30T00:22:21.153       1       1
# 154182  2015-12-30T00:22:21.153       1       1
# 154183  2015-12-30T00:22:21.153       1       1
# 154184  2015-12-30T00:22:21.153       1       1
# 154185  2015-12-30T00:22:21.153       1       1
# 154186  2015-12-30T00:22:21.153       1       1
# 154187  2015-12-30T00:22:21.153       1       1
# 154188  2015-12-30T00:22:21.153       1       1
# 154189  2015-12-29T16:13:27.103       1       1
# 154190  2015-12-29T16:13:27.103       2       2
# 154191  2015-12-29T16:13:27.103       3       3
# 154192  2015-12-29T16:13:27.103       4       4
# 154193  2015-12-29T16:13:27.103       1       1
# 154194  2015-12-29T16:13:27.103       2       2
# 154195  2015-12-29T16:13:27.103       3       3
# 154196  2015-12-29T16:13:27.103       4       4
# 154197  2015-12-31T21:10:31.357       1       1
# 154198  2015-12-31T21:10:31.357       1       1
# 154199  2016-01-02T11:10:43.700       1       1
# 154200  2016-01-02T11:10:43.700       2       2
# 154201  2016-01-02T11:10:43.700       1       1
# 154202  2016-01-02T11:10:43.700       2       2
# 154203  2016-01-02T11:10:43.700       1       1
# 154204  2016-01-02T11:10:43.700       2       2
# 154205  2016-01-01T19:14:14.953       1       1
# 154206  2016-01-01T19:14:14.953       1       1
#
# [154207 rows x 13 columns]

# %%
predictors_raw_vans =['VoteId','VoteCreation','AnsCreation','VoteType','AnsId','QuestionId','AnsWordCount']
get_latest_qv = lambda df :pd.concat(pd[pd.VoteCreation>=pd.QVoteCreation].QVoteCreation.max(),axis=1)
a_votes.sort_values(by='VoteCreation').groupby(['AnsId','VoteId']).apply(get_latest_qv)

# %%
a_votes['AcceptedAge'] = (pd.to_datetime(a_votes.AcceptedDate,format='%Y-%m-%d %H:%M:%S.%f')
                  -pd.to_datetime(a_votes.QuestionCreation,format='%Y-%m-%d %H:%M:%S.%f')).apply(lambda x: x.astype('timedelta64[D]').item().days)
a_votes['AcceptedAge'] = a_votes['AcceptedAge'] + 1

a_votes.loc[a_votes.AcceptedDate == pd.to_datetime('20160320'), 'AcceptedAge'] = -1

a_votes['RelAge'] = (pd.to_datetime(a_votes.VoteCreation,format='%Y-%m-%d %H:%M:%S.%f')
                  -pd.to_datetime(a_votes.AnsCreation,format='%Y-%m-%d %H:%M:%S.%f')).apply(lambda x: x.astype('timedelta64[D]').item().days)
a_votes['RelAge'] = a_votes['RelAge'] + 1

a_votes['Age'] = (pd.to_datetime(a_votes.VoteCreation,format='%Y-%m-%d %H:%M:%S.%f')
                  -pd.to_datetime(a_votes.QuestionCreation,format='%Y-%m-%d %H:%M:%S.%f')).apply(lambda x: x.astype('timedelta64[D]').item().days)
a_votes['Age'] = a_votes['Age'] + 1
# 27         12            1       0     0
# 28         12            1       0     0
# 29         12            1       0     0
# ...       ...          ...     ...   ...
# 22121       3            5       2     2
# 22122       2            4       0     4
# 22123       2           -1       0     0
# 22124       2           -1       5     5
# 22125       2            2       0     0
# 22126       2            2       0     0
# 22127       2            2       2     2
# 22128       2            2       2     2
# 22129       2            2       1     3
# 22130       1            2       0     0
# 22131       1            2       0     0
# 22132       1            2       0     0
# 22133       1            2       0     0
# 22134       1            2       0     0
# 22135       1            2       0     0
# 22136       1            2       0     0
# 22137       1            2       0     0
# 22138       1            2       0     0
# 22139       1            2       1     1
# 22140       1            2       2     2
# 22141       5            1       1     1
# 22142       5            1       4     4
# 22143       1            0       0     0
# 22144       1            1       0     1
# 22145       1            1       0     1
# 22146       2            1       0     0
# 22147       2            1       0     0
# 22148       2            1       1     1
# 22149       1            1       1     1
# 22150       1            1       1     1
#
# [22151 rows x 10 columns]

# %%
a_comments = pd.DataFrame.from_csv('comment-ans.csv', index_col=None)
a_comments = pd.merge(a_comments, a_questions, how='inner', on=['QuestionId'],suffixes=['_vot', '_quest'])

a_comments['Age'] = (pd.to_datetime(a_comments.CommentCreation,format='%Y-%m-%d %H:%M:%S.%f')
                  -pd.to_datetime(a_comments.QuestionCreation,format='%Y-%m-%d %H:%M:%S.%f')).apply(lambda x: x.astype('timedelta64[D]').item().days)
a_comments['Age'] = a_comments['Age'] + 1
a_comments = a_comments[['AnsId','Age']]
a_comments.head(10)
# Out:
#    AnsId   Age
# 0      4     1
# 1      4     1
# 2      5     1
# 3     56     1
# 4     56     1
# 5     56     1
# 6     56     1
# 7   7030   951
# 8   7030  1285
# 9  15104  1436

# %% [markdown]
# ## Each entry in the following tables represents the total votes in an answer in a given day (and associated attributes for the answer and question)

# %%
get_score = lambda df: sum(df.VoteType==2) - sum(df.VoteType==3)
get_votes = lambda df: sum(df.VoteType==2) + sum(df.VoteType==3)

predictors = ['QuestionId','AnsWordCount','AcceptedAnsId','AcceptedAge','QScore','QVotes','Score','Votes']
f = lambda df: pd.Series([df.QuestionId.iloc[0],df.AnsWordCount.iloc[0],df.AcceptedAnsId.iloc[0],df.AcceptedAge.iloc[0],df.QScore.iloc[0],df.QVotes.iloc[0],get_score(df),get_votes(df)],index = predictors)
a_groups = a_votes.sort_values(by='Age').groupby(['AnsId','Age']).apply(f)
a_groups = a_groups.reset_index(level=[0,1],drop=False)
a_groups
# Out:
#        AnsId   Age  QuestionId  AnsWordCount  AcceptedAnsId  AcceptedAge  \
# 0          4     0           1           190             56            6
# 1          4  1436           1           190             56            6
# 2          5     0           1            37             56            6
# 3          5   108           1            37             56            6
# 4          6     0           2            51             10            1
# 5          8     0           2            46             10            1
# 6          9     0           3            25            109          431
# 7          9    12           3            25            109          431
# 8          9   361           3            25            109          431
# 9          9   400           3            25            109          431
# 10         9   614           3            25            109          431
# 11         9  1501           3            25            109          431
# 12        10     0           2           145             10            1
# 13        10     1           2           145             10            1
# 14        10    14           2           145             10            1
# 15        10    25           2           145             10            1
# 16        10   807           2           145             10            1
# 17        10  1317           2           145             10            1
# 15342       1       1      2      2
# 15343       1       1      1      1
# 15344       1       1      1      1
# 15345       2       2      2      2
# 15346       2       2      1      1
#
# [15347 rows x 10 columns]

# %%
cum_votes = lambda df: pd.Series(df['Votes'].cumsum(),name='CumVotes')
cum_score = lambda df: pd.Series(df['Score'].cumsum(),name='CumScore')

f =lambda df: pd.concat([df[cname] for cname in df.columns.values.tolist()] + [cum_votes(df),cum_score(df)],axis=1)
a_groups_c = a_groups.sort_values(by='Age').groupby(['AnsId']).apply(f)
a_groups_c
# Out:
#        AnsId   Age  QuestionId  AnsWordCount  AcceptedAnsId  AcceptedAge  \
# 0          4     0           1           190             56            6
# 9928    5381     0        5379            66           5380            0
# 9926    5380     0        5379            43           5380            0
# 9925    5378     0        5377            51           5378            0
# 2499     867     0         865           138            867           45
# 9921    5375     0        5373           241            NaN           -1
# 9910    5368     0        5367           235           5368            0
# 9908    5366     0        5365            38           5366            0
# 9903    5363     0        5360           389           5363            3
# 9902    5362     0        5360            44           5363            3
# 9900    5359     0        5357           136           5359            0
# 2513     877     0         875            87            877            4
# 9895    5358     0        5350           428            NaN           -1
# 9891    5355     0        5354           116            NaN           -1
# 2517     879     0         875            59            877            4
# 2519     880     0         873           448            880            0
# 9883    5347     0        5344           124            NaN           -1
# 2521     882     0         881           139            882            1
# 9880    5340     0        5339            58            NaN           -1
# 9871    5334     0        5333           213           5334            0
# 9864    5328     0        5323            35           5335            1
# 9861    5327     0        5323            13           5335            1
# 9930    5385     0        5377           126           5378            0
# 9854    5326     0        5325           311           5326            8
# 9933    5386     0        5382           207           5386            4
# 9941    5394     0        5393            17           5394           55
# 10002   5444     0        5438            46           5440            0
# 9990    5442     0        5441            64           5442            0
# 2463     852     0         848             8            853            1
# 2464     853     0         848           191            853            1
# ...      ...   ...         ...           ...            ...          ...
# 1519     467  1453         463            49            465           10
# 6168    2846  1453          38           126           2846          306
# 2547     894  1453         108           132            166            5
# 1459     449  1454         441            19            442            1
# 428       93  1454          84            87            205            1
# 1429     442  1454         441            47            442            1
# 1441     444  1454         441            33            442            1
# 7675    3774  1454         446            92            448           24
# 1660     519  1457         513           303           2323          192
# 2150     718  1459         694            83            696            1
# 2229     751  1459         694            71            696            1
# 6619    3079  1465         319            61            337           16
# 826      205  1465          84           385            205            1
# 15050  15395  1468         172            20            175          121
# 15048  15391  1469           7           124           2977          342
# 15051  15395  1469         172            20            175          121
# 774      203  1469         172            26            175          121
# 645      175  1469         172            44            175          121
# 675      182  1470         172            19            175          121
# 646      175  1470         172            44            175          121
# 562      140  1476         134            93            140           69
# 676      182  1483         172            19            175          121
# 1430     442  1484         441            47            442            1
# 1380     425  1485         418           140            425            0
# 742      191  1491         137           494            191            0
# 1169     335  1496         328           360            335          716
# 743      191  1497         137           494            191            0
# 1170     335  1498         328           360            335          716
# 11         9  1501           3            25            109          431
# 429       93  1504          84            87            205            1
#
#        QScore  QVotes  Score  Votes  CumVotes  CumScore
# 0          12      12      1      3         3         1
# 9928        2       2      2      2         2         2
# 9926        2       2      1      1         1         1
# 9925        1       1      2      2         2         2
# 2463        5       5      1      1         1         1  0.500000  0.833333
# 2464        5       5      1      1         1         1  0.500000  0.833333
# ...       ...     ...    ...    ...       ...       ...       ...       ...
# 1519        7       7      1      1         9         9  0.900000  0.875000
# 6168       22      25      1      1        13        13  0.928571  0.846154
# 2547       33      39      1      1         5         5  0.833333  0.825000
# 1459       11      16      1      1         8         6  0.666667  0.647059
# 428        58      70      1      1        23        23  0.958333  0.816901
# 1429       11      16      1      1        15        15  0.937500  0.647059
# 1441       11      16      1      1        11        11  0.916667  0.647059
# 7675        7       9      1      1         3         3  0.750000  0.700000
# 1660       41      44      1      1        34        32  0.914286  0.911111
# 2150       17      17      1      1         6         6  0.857143  0.944444
# 2229       17      17      1      1         4         4  0.800000  0.944444
# 6619        9      14      1      1         4         4  0.800000  0.600000
# 826        58      70      1      1        62        56  0.888889  0.816901
# 15050      10      10     -1      1         1        -1 -0.500000  0.909091
# 15048      23      26      1      1         1         1  0.500000  0.851852
# 15051      10      10     -1      3         4        -2 -0.400000  0.909091
# 774        10      10      0      2         3         1  0.250000  0.909091
# 645        10      10      1      1        14        14  0.933333  0.909091
# 675        10      10      1      1        19        15  0.750000  0.909091
# 646        10      10      1      1        15        15  0.937500  0.909091
# 562        17      19      1      1        14        14  0.933333  0.850000
# 676        10      10      1      1        20        16  0.761905  0.909091
# 1430       11      16      1      1        16        16  0.941176  0.647059
# 1380       13      13      1      1        19        19  0.950000  0.928571
# 742        40      53      1      1        52        52  0.981132  0.740741
# 1169       21      26      1      1        24        24  0.960000  0.777778
# 743        40      53      1      1        53        53  0.981481  0.740741
# 1170       21      26      1      1        25        25  0.961538  0.777778
# 11         26      30      1      1         9         9  0.900000  0.838710
# 429        58      70      1      1        24        24  0.960000  0.816901
#
# [15347 rows x 14 columns]

# %%
votes_com = pd.merge(a_groups_c, a_comments, how='left', on=['AnsId'],suffixes=['_vot', '_com'])
f = lambda df:pd.concat([df[cname] for cname in df.columns.values.tolist()]+[pd.Series(df['Age_vot']>=df['Age_com'],name='gt')],axis=1)
votes_com = votes_com.groupby(['AnsId']).apply(f)
votes_com.head(10)
# Out:
#    AnsId  Age_vot  QuestionId  AnsWordCount  AcceptedAnsId  AcceptedAge  \
# 0      4        0           1           190             56            6
# 1      4        0           1           190             56            6
# 2   5381        0        5379            66           5380            0
# 3   5380        0        5379            43           5380            0
# 4   5380        0        5379            43           5380            0
# 5   5380        0        5379            43           5380            0
# 6   5380        0        5379            43           5380            0
# 7   5378        0        5377            51           5378            0
# 8    867        0         865           138            867           45
# 9    867        0         865           138            867           45
#
#    QScore  QVotes  Score  Votes  CumVotes  CumScore   ReScore  QReScore  \
# 0      12      12      1      3         3         1  0.250000  0.923077
# 1      12      12      1      3         3         1  0.250000  0.923077
# 2       2       2      2      2         2         2  0.666667  0.666667
# 3       2       2      1      1         1         1  0.500000  0.666667
# 4       2       2      1      1         1         1  0.500000  0.666667
# 5       2       2      1      1         1         1  0.500000  0.666667
# 6       2       2      1      1         1         1  0.500000  0.666667
# 7       1       1      2      2         2         2  0.666667  0.500000
# 8       5       6      2      2         2         2  0.666667  0.714286
# 9       5       6      2      2         2         2  0.666667  0.714286
#
#    Age_com     gt
# 0        1  False
# 1        1  False
# 2      NaN  False
# 3        1  False
# 4        1  False
# 5        1  False
# 6        1  False
# 7      NaN  False
# 8        1  False
# 9        1  False

# %%
tmp_sum_com = votes_com.groupby(['AnsId','Age_vot']).apply(lambda df: sum(df['gt']))
tmp_sum_com.reset_index(drop=False).head(10)
# Out:
#    AnsId  Age_vot  0
# 0      4        0  0
# 1      4     1436  2
# 2      5        0  0
# 3      5      108  1
# 4      6        0  0
# 5      8        0  0
# 6      9        0  0
# 7      9       12  3
# 8      9      361  3
# 9      9      400  3

# %% [markdown]
# ## First Time series cleaned (model for the number of votes)

# %%
votes_com_f = pd.merge(votes_com,tmp_sum_com.reset_index(drop=False),on=['AnsId','Age_vot'],how='inner')
votes_com_f.drop(votes_com_f.columns[[15]], axis=1, inplace=True)
votes_com_f.columns.values[15]='Comments'
votes_com_f = votes_com_f.drop_duplicates()
votes_com_f
# Out:
#        AnsId  Age_vot  QuestionId  AnsWordCount  AcceptedAnsId  AcceptedAge  \
# 0          4        0           1           190             56            6
# 2       5381        0        5379            66           5380            0
# 3       5380        0        5379            43           5380            0
# 7       5378        0        5377            51           5378            0
# 8        867        0         865           138            867           45
# 13       867        0         865           138            867           45
# 14      5375        0        5373           241            NaN           -1
# 15      5375        0        5373           241            NaN           -1
# 17      5368        0        5367           235           5368            0
# 18      5366        0        5365            38           5366            0
# 20      5363        0        5360           389           5363            3
# 21      5362        0        5360            44           5363            3
# 22      5359        0        5357           136           5359            0
# 23      5359        0        5357           136           5359            0
# 24       877        0         875            87            877            4
# 26      5358        0        5350           428            NaN           -1
# 27      5355        0        5354           116            NaN           -1
# 31      5355        0        5354           116            NaN           -1
# 33      5355        0        5354           116            NaN           -1
# 34      5355        0        5354           116            NaN           -1
# 35       879        0         875            59            877            4
# 36       880        0         873           448            880            0
# 37      5347        0        5344           124            NaN           -1
# 38       882        0         881           139            882            1
# 39      5340        0        5339            58            NaN           -1
# 40      5334        0        5333           213           5334            0
# 41      5328        0        5323            35           5335            1
# 44      5327        0        5323            13           5335            1
# 46      5327        0        5323            13           5335            1
# 47      5385        0        5377           126           5378            0
# ...      ...      ...         ...           ...            ...          ...
# 36379    175     1469         172            44            175          121
# 36380    182     1470         172            19            175          121
# 36385    175     1470         172            44            175          121
# 36386    175     1470         172            44            175          121
# 36387    140     1476         134            93            140           69
# 36391    140     1476         134            93            140           69
# 36392    140     1476         134            93            140           69
# 36393    140     1476         134            93            140           69
# 36394    182     1483         172            19            175          121
# 36399    442     1484         441            47            442            1
# 36400    442     1484         441            47            442            1
# 36401    442     1484         441            47            442            1
# 36402    442     1484         441            47            442            1
# 36403    442     1484         441            47            442            1
# 36404    425     1485         418           140            425            0
# 36405    191     1491         137           494            191            0
# 36408    191     1491         137           494            191            0
# 36410    191     1491         137           494            191            0
# 36411    191     1491         137           494            191            0
# 36412    335     1496         328           360            335          716
# 36413    191     1497         137           494            191            0
# 36416    191     1497         137           494            191            0
# 36416      40      53      1      1        53        53  0.981481  0.740741
# 36418      40      53      1      1        53        53  0.981481  0.740741
# 36419      40      53      1      1        53        53  0.981481  0.740741
# 36420      21      26      1      1        25        25  0.961538  0.777778
# 36421      26      30      1      1         9         9  0.900000  0.838710
# 36424      58      70      1      1        24        24  0.960000  0.816901
# 36426      58      70      1      1        24        24  0.960000  0.816901
# 36427      58      70      1      1        24        24  0.960000  0.816901
# 36431      58      70      1      1        24        24  0.960000  0.816901
#
#        Age_com  Comments
# 0            1         0
# 2          NaN         0
# 3            1         0
# 7          NaN         0
# 8            1         0
# 13           2         0
# 14           1         0
# 15           2         0
# 17           1         0
# 18           1         0
# 20           1         0
# 21         NaN         0
# 22           1         0
# 23           2         0
# 24           1         0
# 26         NaN         0
# 27           1         0
# 31           2         0
# 33           3         0
# 34          36         0
# 35         NaN         0
# 36         NaN         0
# 37         NaN         0
# 38         NaN         0
# 39         NaN         0
# 40           1         0
# 41           2         0
# 44           1         0
# 46           2         0
# 47         564         0
# ...        ...       ...
# 36379     1470         1
# 36380        1         5
# 36385        1         2
# 36386     1470         2
# 36387        1         7
# 36391     1038         7
# 36392     1317         7
# 36393     1318         7
# 36394        1         5
# 36399        1         5
# 36400       43         5
# 36401       44         5
# 36402      448         5
# 36403     1351         5
# 36404        1         1
# 36405        1         7
# 36408       84         7
# 36410      140         7
# 36411     1123         7
# 36412     1173         1
# 36413        1         7
# 36416       84         7
# 36418      140         7
# 36419     1123         7
# 36420     1173         1
# 36421        1         3
# 36424        1         8
# 36426       56         8
# 36427      169         8
# 36431     1452         8
#
# [23468 rows x 16 columns]

# %% [markdown]
# # Check inconsistent entries

# %%
votes_com_f[(votes_com_f['AnsId'].isnull()) | (votes_com_f['Age_vot'].isnull()) | (votes_com_f['Votes'].isnull()) | (votes_com_f['Score'].isnull()) | (votes_com_f['Comments'].isnull())]
# Out:
# Empty DataFrame
# Columns: [AnsId, Age_vot, QuestionId, AnsWordCount, AcceptedAnsId, AcceptedAge, QScore, QVotes, Score, Votes, CumVotes, CumScore, ReScore, QReScore, Age_com, Comments]
# Index: []

# %%
votes_com_f[votes_com_f.Age_vot < 0]
# Out:
# Empty DataFrame
# Columns: [AnsId, Age_vot, QuestionId, AnsWordCount, AcceptedAnsId, AcceptedAge, QScore, QVotes, Score, Votes, CumVotes, CumScore, ReScore, QReScore, Age_com, Comments]
# Index: []

# %%
votes_com_f[votes_com_f.CumScore>votes_com_f.CumVotes]
# Out:
# Empty DataFrame
# Columns: [AnsId, Age_vot, QuestionId, AnsWordCount, AcceptedAnsId, AcceptedAge, QScore, QVotes, Score, Votes, CumVotes, CumScore, ReScore, QReScore, Age_com, Comments]
# Index: []

# %%
#Accepted answers 687 and 990 didn't have acceptance dates registered?
votes_com_f[(votes_com_f['AcceptedAnsId'].notnull()) & (votes_com_f['AcceptedAge']<0)]
# Out:
#        AnsId  Age_vot  QuestionId  AnsWordCount  AcceptedAnsId  AcceptedAge  \
# 769      990        0         987            62            990           -1
# 772      990        0         987            62            990           -1
# 773      990        0         987            62            990           -1
# 774      990        0         987            62            990           -1
# 1933     687        0         686            31            687           -1
# 1939     688        0         686            26            687           -1
# 1942     689        0         686            48            687           -1
# 1947     690        0         686            39            687           -1
# 15927    687        4         686            31            687           -1
# 23652    687       35         686            31            687           -1
# 26246    990      121         987            62            990           -1
# 26249    990      121         987            62            990           -1
# 26250    990      121         987            62            990           -1
# 26251    990      121         987            62            990           -1
# 27757   2647      224         987            64            990           -1
# 28041    689      256         686            48            687           -1
# 29817    687      435         686            31            687           -1
# 31987   4708      748         987           152            990           -1
#
#        QScore  QVotes  Score  Votes  CumVotes  CumScore   ReScore  QReScore  \
# 769         6       6      1      1         1         1  0.500000  0.857143
# 772         6       6      1      1         1         1  0.500000  0.857143
# 773         6       6      1      1         1         1  0.500000  0.857143
# 774         6       6      1      1         1         1  0.500000  0.857143
# 1933        4       4      5      5         5         5  0.833333  0.800000
# 1939        4       4      4      4         4         4  0.800000  0.800000
# 1942        4       4      3      3         3         3  0.750000  0.800000
# 1947        4       4      1      1         1         1  0.500000  0.800000
# 15927       4       4      1      1         6         6  0.857143  0.800000
# 23652       4       4      1      1         7         7  0.875000  0.800000
# 26246       6       6      1      1         2         2  0.666667  0.857143
# 26249       6       6      1      1         2         2  0.666667  0.857143
# 26250       6       6      1      1         2         2  0.666667  0.857143
# 26251       6       6      1      1         2         2  0.666667  0.857143
# 27757       6       6      2      2         2         2  0.666667  0.857143
# 28041       4       4      1      1         4         4  0.800000  0.800000
# 29817       4       4      1      1         8         8  0.888889  0.800000
# 31987       6       6     -1      1         1        -1 -0.500000  0.857143
#
#        Age_com  Comments
# 769          1         0
# 772         64         0
# 773         70         0
# 774         76         0
# 1933         1         0
# 1939         1         0
# 1942         1         0
# 1947       NaN         0
# 15927        1         5
# 23652        1         5
# 26246        1         6
# 26249       64         6
# 26250       70         6
# 26251       76         6
# 27757      NaN         0
# 28041        1         4
# 29817        1         5
# 31987      NaN         0

# %% [markdown]
# ## Calculate Rank

# %%
from itertools import izip
def rank_ans(df,score_only,re_score):
    rk_name = "ReScore_rank" if re_score else "AnsRank"
    def rank_iter():
        cache = {}
        accepted = 0
        for row in df.itertuples():
            if re_score:
                cache[row.AnsId] = row.ReScore
            else :
                cache[row.AnsId] = row.Score
            # rank, nb_ans
            if (not score_only) and row.AcceptedAge>-1 and (row.AnsId == row.AcceptedAnsId) and row.Age_vot >=row.AcceptedAge:
                accepted = 1
                if row.AnsId in cache:
                    del cache[row.AnsId]
                yield (1,len(cache)+accepted,row.Index)
            else :
                rank = sorted(cache, key= lambda k:cache[k],reverse=True).index(row.AnsId) + 1 + accepted
                yield (rank,len(cache)+accepted,row.Index)
            
    ranks, ans_counts, indices = izip(*list(rank_iter())) #TODO: optimize for the future
    return [pd.Series(ranks,name=rk_name, index=indices), pd.Series(ans_counts,name="Ans_count", index=indices)]

predictors = ['AnsId','Comments','AnsWordCount','AcceptedAnsId','Age_vot','Score','Votes','CumScore','CumVotes','QScore','QVotes','ReScore','QReScore','AnsRank','ReScore_rank']
get_ranks = lambda df,score_only=False,re_score=False: pd.concat([df[cname] for cname in df.columns.values.tolist() if cname in predictors] + rank_ans(df,score_only,re_score),axis=1)
sort_age_score = lambda df: df.sort_values(by=['Age_vot','Score'],ascending=[True,False])

# %% [markdown]
# ## Base data for model

# %%
votes_com_f = votes_com_f.groupby(['QuestionId']).apply(lambda df: get_ranks(sort_age_score(df)))
votes_com_f = votes_com_f.reset_index(level=[0],drop=False)
votes_com_f = votes_com_f.groupby(['QuestionId']).apply(lambda df: get_ranks(sort_age_score(df),score_only=True,re_score=True))
votes_com_f = votes_com_f.reset_index(level=[0],drop=False)

votes_com_f['Pbias'] = 1.0/votes_com_f['AnsRank']
votes_com_f['DRank'] = votes_com_f['AnsRank'] - votes_com_f['ReScore_rank']
votes_com_f.head(20)
# Out:
#        QuestionId  AnsId  Age_vot  AnsWordCount  AcceptedAnsId  QScore  \
# 4226            1     56        0           201             56      12
# 0               1      4        0           190             56      12
# 5381            1      5        0            37             56      12
# 10271           1     56        1           201             56      12
# 10562           1    210        1            40             56      12
# 16037           1    210        4            40             56      12
# 16356           1     56        4           201             56      12
# 19009           1     56        7           201             56      12
# 26040           1    897      108            68             56      12
# 26035           1      5      108            37             56      12
# 26853           1     56      157           201             56      12
# 33088           1     56      905           201             56      12
# 33434           1   7030      951           145             56      12
# 33435           1   7030      951           145             56      12
# 34986           1   7030     1231           145             56      12
# 34987           1   7030     1231           145             56      12
# 35152           1   7030     1255           145             56      12
# 35153           1   7030     1255           145             56      12
# 35291           1   7030     1284           145             56      12
# 35292           1   7030     1284           145             56      12
#
#        QVotes  Score  Votes  CumVotes  CumScore   ReScore  QReScore  Comments  \
# 4226       12      2      2         2         2  0.666667  0.923077         0
# 0          12      1      3         3         1  0.250000  0.923077         0
# 5381       12      1      1         1         1  0.500000  0.923077         0
# 10271      12      3      3         5         5  0.833333  0.923077         4
# 10562      12      1      1         1         1  0.500000  0.923077         0
# 16037      12      1      1         2         2  0.666667  0.923077         0
# 16356      12      1      1         6         6  0.857143  0.923077         4
# 19009      12      1      1         7         7  0.875000  0.923077         4
# 26040      12      1      1         1         1  0.500000  0.923077         0
# 26035      12     -1      1         2         0  0.000000  0.923077         1
# 26853      12      1      1         8         8  0.888889  0.923077         4
# 33088      12      1      1         9         9  0.900000  0.923077         4
# 33434      12      1      1         1         1  0.500000  0.923077         1
# 33435      12      1      1         1         1  0.500000  0.923077         1
# 34986      12      1      1         2         2  0.666667  0.923077         1
# 34987      12      1      1         2         2  0.666667  0.923077         1
# 35152      12      1      1         3         3  0.750000  0.923077         1
# 35153      12      1      1         3         3  0.750000  0.923077         1
# 35291      12      1      1         4         4  0.800000  0.923077         1
# 35292      12      1      1         4         4  0.800000  0.923077         1
#
#        AnsRank  ReScore_rank  Ans_count     Pbias  DRank
# 4226         1             1          1  1.000000      0
# 0            2             2          2  0.500000      0
# 5381         3             2          3  0.333333      1
# 10271        1             1          3  1.000000      0
# 10562        2             2          4  0.500000      0
# 16037        2             2          4  0.500000      0
# 16356        1             1          4  1.000000      0
# 19009        1             1          4  1.000000      0
# 26040        2             3          5  0.500000     -1
# 26035        5             5          5  0.200000      0
# 26853        1             1          5  1.000000      0
# 33088        1             1          5  1.000000      0
# 33434        5             4          6  0.200000      1
# 33435        5             4          6  0.200000      1
# 34986        5             3          6  0.200000      2
# 34987        5             3          6  0.200000      2
# 35152        5             2          6  0.200000      3
# 35153        5             2          6  0.200000      3
# 35291        5             2          6  0.200000      3
# 35292        5             2          6  0.200000      3

# %%
votes = votes_com_f.reset_index(level=[0],drop=False)
votes[['Age_vot','AnsWordCount','Comments','Ans_count']].describe()
# Out:
#             Age_vot  AnsWordCount      Comments     Ans_count
# count  23468.000000  23468.000000  23468.000000  23468.000000
# mean     211.678797    143.299301      2.028720      2.717402
# std      379.776249    150.011670      2.848235      2.062204
# min        0.000000      3.000000      0.000000      1.000000
# 25%        1.000000     51.000000      0.000000      1.000000
# 50%        7.000000     97.000000      1.000000      2.000000
# 75%      227.000000    178.000000      3.000000      3.000000
# max     1504.000000   2142.000000     18.000000     12.000000

# %%
votes['Ans_count'].value_counts().head(15)
# Out:
# 1    5681
# 2    3850
# 3    1546
# 4     598
# 5     191
# 9      77
# 6      66
# 8      26
# 7      19
# Name: Ans_count, dtype: int64

# %%
#votes = votes[ votes.age_vot>=3]
votes = votes[votes.Age_vot<=7]
votes[['Score','Votes','CumScore','CumVotes','QScore','QVotes','ReScore','QReScore','Ans_count','DRank']].describe()
# Out:
#               Score         Votes      CumScore      CumVotes        QScore  \
# count  12054.000000  12054.000000  12054.000000  12054.000000  12054.000000
# mean       1.672557      1.785217      3.328688      3.495935      5.786959
# std        1.401087      1.323257      2.636213      2.570072      7.294079
# min       -3.000000      1.000000     -6.000000      1.000000     -7.000000
# 25%        1.000000      1.000000      1.000000      2.000000      2.000000
# 50%        1.000000      1.000000      3.000000      3.000000      4.000000
# 75%        2.000000      2.000000      5.000000      5.000000      7.000000
# max       12.000000     12.000000     18.000000     18.000000     58.000000
#
#              QVotes       ReScore      QReScore     Ans_count         DRank
# count  12054.000000  12054.000000  12054.000000  12054.000000  12054.000000
# mean       6.913307      0.667193      0.668451      1.891156      0.069106
# std        8.808227      0.233378      0.220706      1.202724      0.596975
# min        1.000000     -0.857143     -0.875000      1.000000     -5.000000
# 25%        3.000000      0.500000      0.600000      1.000000      0.000000
# 50%        5.000000      0.750000      0.750000      2.000000      0.000000
# 75%        8.000000      0.833333      0.800000      2.000000      0.000000
# max       70.000000      0.947368      0.944444      9.000000      8.000000

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %% [markdown]
# # How does question quality relate to answer quality

# %%
one_ans = smf.ols(formula='QReScore ~ ReScore + C(AnsRank) - 1', data=votes[votes['Ans_count']==1])
re_one = one_ans.fit()
print re_one.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               QReScore   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     218.3
# Date:                Fri, 01 Apr 2016   Prob (F-statistic):           1.71e-48
# Time:                        06:28:51   Log-Likelihood:                 214.23
# No. Observations:                5681   AIC:                            -424.5
# Df Residuals:                    5679   BIC:                            -411.2
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# C(AnsRank)[1]     0.4567      0.013     33.894      0.000         0.430     0.483
# ReScore           0.2753      0.019     14.773      0.000         0.239     0.312
# ==============================================================================
# Omnibus:                     2657.604   Durbin-Watson:                   0.814
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15956.703
# Skew:                          -2.190   Prob(JB):                         0.00
# Kurtosis:                       9.944   Cond. No.                         9.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
two_ans = smf.ols(formula='QReScore ~ ReScore + C(AnsRank) - 1', data=votes[votes['Ans_count']==2])
re_two = two_ans.fit()
print re_two.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               QReScore   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     37.93
# Date:                Fri, 01 Apr 2016   Prob (F-statistic):           4.85e-17
# Time:                        06:28:55   Log-Likelihood:                 510.14
# No. Observations:                3850   AIC:                            -1014.
# Df Residuals:                    3847   BIC:                            -995.5
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# C(AnsRank)[1]     0.5824      0.011     51.366      0.000         0.560     0.605
# C(AnsRank)[2]     0.6012      0.009     66.853      0.000         0.584     0.619
# ReScore           0.1186      0.014      8.709      0.000         0.092     0.145
# ==============================================================================
# Omnibus:                     1846.238   Durbin-Watson:                   0.630
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13158.841
# Skew:                          -2.174   Prob(JB):                         0.00
# Kurtosis:                      10.945   Cond. No.                         5.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
three_ans = smf.ols(formula='QVotes ~ CumVotes + C(AnsRank) - 1', data=votes[votes['Ans_count']==3])
re_three = three_ans.fit()
print re_three.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 QVotes   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     79.67
# Date:                Fri, 01 Apr 2016   Prob (F-statistic):           6.46e-48
# Time:                        06:28:56   Log-Likelihood:                -5253.4
# No. Observations:                1546   AIC:                         1.051e+04
# Df Residuals:                    1542   BIC:                         1.054e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# C(AnsRank)[1]     3.7489      0.506      7.408      0.000         2.756     4.742
# C(AnsRank)[2]     3.4219      0.426      8.032      0.000         2.586     4.258
# C(AnsRank)[3]     4.5130      0.335     13.490      0.000         3.857     5.169
# CumVotes          1.0633      0.073     14.524      0.000         0.920     1.207
# ==============================================================================
# Omnibus:                     1048.200   Durbin-Watson:                   0.472
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15162.055
# Skew:                           3.018   Prob(JB):                         0.00
# Kurtosis:                      17.105   Cond. No.                         14.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
four_ans = smf.ols(formula='QReScore ~ ReScore + C(AnsRank) - 1', data=votes[votes['Ans_count']==4])
re_four = four_ans.fit()
print re_four.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               QReScore   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     11.63
# Date:                Fri, 01 Apr 2016   Prob (F-statistic):           4.28e-09
# Time:                        06:29:00   Log-Likelihood:                 150.68
# No. Observations:                 598   AIC:                            -291.4
# Df Residuals:                     593   BIC:                            -269.4
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# C(AnsRank)[1]     0.5631      0.024     23.715      0.000         0.516     0.610
# C(AnsRank)[2]     0.5973      0.024     25.161      0.000         0.551     0.644
# C(AnsRank)[3]     0.6165      0.022     28.419      0.000         0.574     0.659
# C(AnsRank)[4]     0.6399      0.017     36.824      0.000         0.606     0.674
# ReScore           0.1610      0.025      6.572      0.000         0.113     0.209
# ==============================================================================
# Omnibus:                      288.982   Durbin-Watson:                   0.614
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1972.127
# Skew:                          -2.042   Prob(JB):                         0.00
# Kurtosis:                      10.904   Cond. No.                         4.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
five_ans = smf.ols(formula='QReScore ~ ReScore + C(AnsRank) - 1', data=votes[votes['Ans_count']==5])
re_five = five_ans.fit()
print re_five.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               QReScore   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     4.201
# Date:                Fri, 01 Apr 2016   Prob (F-statistic):            0.00122
# Time:                        06:29:02   Log-Likelihood:                 120.41
# No. Observations:                 191   AIC:                            -228.8
# Df Residuals:                     185   BIC:                            -209.3
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# C(AnsRank)[1]     0.5596      0.035     16.175      0.000         0.491     0.628
# C(AnsRank)[2]     0.5576      0.038     14.649      0.000         0.482     0.633
# C(AnsRank)[3]     0.6374      0.041     15.424      0.000         0.556     0.719
# C(AnsRank)[4]     0.6305      0.031     20.088      0.000         0.569     0.692
# C(AnsRank)[5]     0.6328      0.027     23.815      0.000         0.580     0.685
# ReScore           0.1392      0.040      3.505      0.001         0.061     0.218
# ==============================================================================
# Omnibus:                        1.732   Durbin-Watson:                   0.593
# Prob(Omnibus):                  0.421   Jarque-Bera (JB):                1.741
# Skew:                          -0.169   Prob(JB):                        0.419
# Kurtosis:                       2.676   Cond. No.                         6.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print "Pearson r Score-position: ", votes['Score'].corr(votes['AnsRank'],method='pearson')
# Out:
# Pearson r Score-position:  -0.261224567951

# %% [markdown]
# ## Mixed effects model for votes

# %%
formula = "np.log(Votes+1) ~ C(AnsRank) - 1"
model = sm.MixedLM.from_formula(formula, votes, re_formula="AnsRank", groups=votes["AnsId"])
result = model.fit()
print result.summary()
# Out:
# c:\Users\Joel\Anaconda2\lib\site-packages\statsmodels\base\model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# c:\Users\Joel\Anaconda2\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1717: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:              MixedLM   Dependent Variable:   np.log(Votes + 1)
# No. Observations:   12054     Method:               REML
# No. Groups:         4594      Scale:                0.0965
# Min. group size:    1         Likelihood:           -4144.6903
# Max. group size:    70        Converged:            Yes
# Mean group size:    2.6
# ---------------------------------------------------------------------
#                           Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# C(AnsRank)[1]              1.017    0.005 191.155 0.000  1.007  1.027
# C(AnsRank)[2]              0.840    0.007 126.444 0.000  0.827  0.853
# C(AnsRank)[3]              0.772    0.011  70.549 0.000  0.751  0.794
# C(AnsRank)[4]              0.792    0.020  39.025 0.000  0.752  0.832
# C(AnsRank)[5]              0.770    0.041  18.851 0.000  0.690  0.850
# C(AnsRank)[6]              0.838    0.072  11.622 0.000  0.697  0.979
# C(AnsRank)[7]              0.931    0.146   6.368 0.000  0.645  1.218
# C(AnsRank)[8]              1.243    0.238   5.225 0.000  0.777  1.709
# C(AnsRank)[9]              0.845    0.201   4.202 0.000  0.451  1.239
# Intercept RE               0.079    0.020
# Intercept RE x AnsRank RE -0.024    0.009
# AnsRank RE                 0.007    0.004
# =====================================================================

# %%
formula = "np.log(Votes+1) ~ C(AnsRank,Helmert) - 1"
model = sm.MixedLM.from_formula(formula, votes, re_formula="AnsRank", groups=votes["AnsId"])
result = model.fit()
print result.summary()
# Out:
#                     Mixed Linear Model Regression Results
# ============================================================================
# Model:                 MixedLM     Dependent Variable:     np.log(Votes + 1)
# No. Observations:      12054       Method:                 REML
# No. Groups:            4594        Scale:                  0.0965
# Min. group size:       1           Likelihood:             -4157.5194
# Max. group size:       70          Converged:              Yes
# Mean group size:       2.6
# ----------------------------------------------------------------------------
#                                  Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------
# C(AnsRank, Helmert)[H.intercept]  0.893    0.045  19.996 0.000  0.805  0.981
# C(AnsRank, Helmert)[H.2]         -0.089    0.004 -21.516 0.000 -0.097 -0.081
# C(AnsRank, Helmert)[H.3]         -0.052    0.004 -13.306 0.000 -0.060 -0.044
# C(AnsRank, Helmert)[H.4]         -0.021    0.005  -4.058 0.000 -0.031 -0.011
# C(AnsRank, Helmert)[H.5]         -0.017    0.008  -2.076 0.038 -0.033 -0.001
# C(AnsRank, Helmert)[H.6]         -0.000    0.012  -0.022 0.983 -0.024  0.023
# C(AnsRank, Helmert)[H.7]          0.014    0.021   0.680 0.496 -0.027  0.055
# C(AnsRank, Helmert)[H.8]          0.050    0.029   1.701 0.089 -0.008  0.107
# C(AnsRank, Helmert)[H.9]         -0.009    0.022  -0.383 0.702 -0.053  0.035
# Intercept RE                      0.079    0.020
# Intercept RE x AnsRank RE        -0.024    0.009
# AnsRank RE                        0.007    0.004
# ============================================================================
# c:\Users\Joel\Anaconda2\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1717: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
formula = "np.log(Votes+1) ~ C(AnsRank,Diff) - 1"
model = sm.MixedLM.from_formula(formula, votes, re_formula="AnsRank", groups=votes["AnsId"])
result = model.fit()
print result.summary()
# Out:
# c:\Users\Joel\Anaconda2\lib\site-packages\statsmodels\base\model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# c:\Users\Joel\Anaconda2\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1717: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:              MixedLM   Dependent Variable:   np.log(Votes + 1)
# No. Observations:   12054     Method:               REML
# No. Groups:         4594      Scale:                0.0965
# Min. group size:    1         Likelihood:           -4144.7526
# Max. group size:    70        Converged:            Yes
# Mean group size:    2.6
# ---------------------------------------------------------------------
#                           Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# C(AnsRank, Diff)[D.1]      0.892    0.045  19.975 0.000  0.805  0.980
# C(AnsRank, Diff)[D.2]     -0.177    0.008 -21.518 0.000 -0.194 -0.161
# C(AnsRank, Diff)[D.3]     -0.067    0.013  -5.304 0.000 -0.092 -0.042
# C(AnsRank, Diff)[D.4]      0.020    0.023   0.871 0.384 -0.025  0.065
# C(AnsRank, Diff)[D.5]     -0.023    0.045  -0.499 0.618 -0.111  0.066
# C(AnsRank, Diff)[D.6]      0.062    0.081   0.774 0.439 -0.096  0.221
# C(AnsRank, Diff)[D.7]      0.137    0.160   0.856 0.392 -0.176  0.449
# C(AnsRank, Diff)[D.8]      0.265    0.247   1.075 0.282 -0.218  0.748
# C(AnsRank, Diff)[D.9]     -0.427    0.305  -1.397 0.162 -1.025  0.172
# Intercept RE               0.079    0.020
# Intercept RE x AnsRank RE -0.024    0.009
# AnsRank RE                 0.007    0.004
# =====================================================================

# %% [markdown]
# ## OLS, Poisson, RobustLM

# %%
mod_ols = smf.ols(formula='np.log(Votes+1) ~ AnsRank + ReScore_rank - 1', data=votes[(votes.Ans_count<=4)])#&(votes.DRank==2)])
res = mod_ols.fit()
print res.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(Votes + 1)   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                 1.182e+04
# Date:                Fri, 01 Apr 2016   Prob (F-statistic):               0.00
# Time:                        07:29:38   Log-Likelihood:                -10310.
# No. Observations:               11675   AIC:                         2.062e+04
# Df Residuals:                   11673   BIC:                         2.064e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# AnsRank          0.1906      0.011     16.631      0.000         0.168     0.213
# ReScore_rank     0.3549      0.012     29.537      0.000         0.331     0.378
# ==============================================================================
# Omnibus:                       77.629   Durbin-Watson:                   1.171
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.186
# Skew:                          -0.016   Prob(JB):                     3.58e-26
# Kurtosis:                       3.490   Cond. No.                         6.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod_poi = smf.glm('Votes ~ Score + Ans_rank + AnsWordCount + Comments  + Ans_count - 1 ', data=votes,
                  family=sm.families.Poisson(link=sm.families.links.log)).fit(method='bfgs') #
#print mod_poi.mle_retvals['converged']
print mod_poi.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  Votes   No. Observations:                 9364
# Model:                            GLM   Df Residuals:                     9359
# Model Family:                 Poisson   Df Model:                            4
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -13488.
# Date:                Sun, 20 Mar 2016   Deviance:                       6748.6
# Time:                        06:55:20   Pearson chi2:                 6.14e+03
# No. Iterations:                     8
# ================================================================================
#                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Score            0.1245      0.003     48.930      0.000         0.120     0.130
# Ans_rank         0.1981      0.011     17.433      0.000         0.176     0.220
# AnsWordCount     0.0006   5.96e-05      9.745      0.000         0.000     0.001
# Comments        -0.0716      0.006    -12.824      0.000        -0.083    -0.061
# Ans_count       -0.1458      0.010    -14.190      0.000        -0.166    -0.126
# ================================================================================

# %%
huber_t = sm.RLM(np.log(votes.Votes + 1), votes[['age_vot','Score', 'Comments','Ans_rank','Ans_count']], M=sm.robust.norms.HuberT())
hub_results = huber_t.fit()

#print hub_results.params
#print hub_results.bse
#varnames = ['var_%d' % i for i in range(len(hub_results.params))]
print hub_results.summary()
# Out:
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  Votes   No. Observations:                 2669
# Model:                            RLM   Df Residuals:                     2664
# Method:                          IRLS   Df Model:                            4
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Thu, 17 Mar 2016
# Time:                        04:50:12
# No. Iterations:                    25
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# age_vot        0.0285      0.001     23.031      0.000         0.026     0.031
# Score          0.0483      0.001     37.198      0.000         0.046     0.051
# Comments       0.0165      0.002      8.456      0.000         0.013     0.020
# Ans_rank       0.1539      0.005     32.435      0.000         0.145     0.163
# Ans_count      0.0159      0.003      5.503      0.000         0.010     0.022
# ==============================================================================
#
# If the model instance has been used for another fit with different fit
# parameters, then the fit options might not be the correct ones anymore .
